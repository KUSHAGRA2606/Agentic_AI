# %% [markdown]
# ## Document Preprocessing

# %%
import fitz
from tqdm.auto import tqdm

pdf_path = "trial_paper.pdf"

def text_formatter(text: str) -> str:
    return text.replace("\n", " ").strip()

doc = fitz.open(pdf_path)
pages_and_texts = []

for page_number, page in tqdm(enumerate(doc)):
    text = page.get_text()
    text = text_formatter(text)
    
    pages_and_texts.append({
        "page_number": page_number,
        "page_char_count": len(text),
        "page_word_count": len(text.split(" ")),
        "text": text
    })
# Out:
# 35it [00:00, 118.89it/s]

# %% [markdown]
# ## Sentence Splitting and Chunking

# %%
from spacy.lang.en import English
import pandas as pd
import re

nlp = English()
nlp.add_pipe("sentencizer")

for item in tqdm(pages_and_texts):
    item["sentences"] = [str(sentence) for sentence in nlp(item["text"]).sents]
    
chunk_size = 10
def split_list(input_list: list, slice_size: int) -> list[list[str]]:
    return [input_list[i:i + slice_size] for i in range(0, len(input_list), slice_size)]

for item in tqdm(pages_and_texts):
    item["sentence_chunks"] = split_list(input_list=item["sentences"], slice_size=chunk_size)

pages_and_chunks = []
for item in tqdm(pages_and_texts):
    for sentence_chunk in item["sentence_chunks"]:
        chunk_dict = {}
        chunk_dict["page_number"] = item["page_number"]
        
        joined_sentence_chunk = "".join(sentence_chunk).replace("  ", " ").strip()
        joined_sentence_chunk = re.sub(r'\.([A-Z])', r'. \1', joined_sentence_chunk) 
        
        chunk_dict["sentence_chunk"] = joined_sentence_chunk
        chunk_dict["chunk_char_count"] = len(joined_sentence_chunk)
        chunk_dict["chunk_word_count"] = len([word for word in joined_sentence_chunk.split(" ")])
        chunk_dict["chunk_token_count"] = len(joined_sentence_chunk) / 4 # roughly 4 chars per token
        
        pages_and_chunks.append(chunk_dict)

min_token_length = 30
pages_and_chunks = [chunk for chunk in pages_and_chunks if chunk["chunk_token_count"] > min_token_length]
# Out:
# 100%|██████████| 35/35 [00:00<00:00, 541.67it/s]
# 100%|██████████| 35/35 [00:00<00:00, 614228.62it/s]
# 100%|██████████| 35/35 [00:00<00:00, 28111.96it/s]

# %% [markdown]
# ## Embedding Creation

# %%
import torch
from sentence_transformers import SentenceTransformer

device = "cuda" if torch.cuda.is_available() else "cpu"

embedding_model = SentenceTransformer(model_name_or_path="all-mpnet-base-v2", device=device)

text_chunks = [item["sentence_chunk"] for item in pages_and_chunks]

embeddings = embedding_model.encode(
    text_chunks,
    batch_size=32, 
    convert_to_tensor=True
)

for i, item in enumerate(pages_and_chunks):
    item["embedding"] = embeddings[i]
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 21002.65it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 10
#       6 embedding_model = SentenceTransformer(model_name_or_path="all-mpnet-base-v2", device=device)
#       7
#       8 text_chunks = [item["sentence_chunk"] for item in pages_and_chunks]
#       9
# ---> 10 embeddings = embedding_model.encode(
#      11     text_chunks,
#      12     batch_size=32,
#      13     convert_to_tensor=True
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/sentence_transformers/util/decorators.py:41, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      39         else:
#      40             kwargs.pop(old_name)
# ---> 41 return func(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/sentence_transformers/sentence_transformer/model.py:657, in SentenceTransformer.encode(self, inputs, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#     653     features = self._pad_features_for_hpu(features)
#     655 features = batch_to_device(features, device)
# --> 657 out_features = self.forward(features, **kwargs)
#     658 if is_hpu:
#     659     out_features = copy.deepcopy(out_features)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/sentence_transformers/base/model.py:492, in BaseModel.forward(self, input, **kwargs)
#     486             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     487         module_kwargs = {
#     488             key: value
#     489             for key, value in kwargs.items()
#     490             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#     491         }
# --> 492     input = module(input, **module_kwargs)
#     493 return input
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/sentence_transformers/base/modules/transformer.py:1090, in Transformer.forward(self, features, **kwargs)
#    1087 if method_output_name is not None and "hidden_states" in method_output_name:
#    1088     filtered_kwargs["output_hidden_states"] = True
# -> 1090 model_output = model_method(**filtered_kwargs)
#    1092 embedding = model_output
#    1093 if method_output_name is not None:
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/transformers/models/mpnet/modeling_mpnet.py:423, in MPNetModel.forward(self, input_ids, attention_mask, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     415 embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
#     417 attention_mask = create_bidirectional_mask(
#     418     config=self.config,
#     419     inputs_embeds=embedding_output,
#     420     attention_mask=attention_mask,
#     421 )
# --> 423 encoder_outputs = self.encoder(
#     424     embedding_output,
#     425     attention_mask=attention_mask,
#     426     output_attentions=output_attentions,
#     427     output_hidden_states=output_hidden_states,
#     428     return_dict=return_dict,
#     429 )
#     430 sequence_output = encoder_outputs[0]
#     431 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/transformers/models/mpnet/modeling_mpnet.py:290, in MPNetEncoder.forward(self, hidden_states, attention_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     287 if output_hidden_states:
#     288     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 290 layer_outputs = layer_module(
#     291     hidden_states,
#     292     attention_mask,
#     293     position_bias,
#     294     output_attentions=output_attentions,
#     295     **kwargs,
#     296 )
#     297 hidden_states = layer_outputs[0]
#     299 if output_attentions:
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/transformers/models/mpnet/modeling_mpnet.py:251, in MPNetLayer.forward(self, hidden_states, attention_mask, position_bias, output_attentions, **kwargs)
#     243 def forward(
#     244     self,
#     245     hidden_states,
#    (...)    249     **kwargs,
#     250 ):
# --> 251     self_attention_outputs = self.attention(
#     252         hidden_states,
#     253         attention_mask,
#     254         position_bias=position_bias,
#     255         output_attentions=output_attentions,
#     256     )
#     257     attention_output = self_attention_outputs[0]
#     258     outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/transformers/models/mpnet/modeling_mpnet.py:194, in MPNetAttention.forward(self, hidden_states, attention_mask, position_bias, output_attentions, **kwargs)
#     186 def forward(
#     187     self,
#     188     hidden_states,
#    (...)    192     **kwargs,
#     193 ):
# --> 194     self_outputs = self.attn(
#     195         hidden_states,
#     196         attention_mask,
#     197         position_bias,
#     198         output_attentions=output_attentions,
#     199     )
#     200     attention_output = self.LayerNorm(self.dropout(self_outputs[0]) + hidden_states)
#     201     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/archit/python/RAG/.venv/lib/python3.14/site-packages/transformers/models/mpnet/modeling_mpnet.py:152, in MPNetSelfAttention.forward(self, hidden_states, attention_mask, position_bias, output_attentions, **kwargs)
#     149 v = self.v(hidden_states).view(hidden_shape).transpose(1, 2)
#     151 # Take the dot product between "query" and "key" to get the raw attention scores.
# --> 152 attention_scores = torch.matmul(q, k.transpose(-1, -2))
#     153 attention_scores = attention_scores / math.sqrt(self.attention_head_size)
#     155 # Apply relative position embedding (precomputed in MPNetEncoder) if provided.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Retrieval

# %%
from sentence_transformers import util

def retrieve_relevant_resources(query: str, embeddings: torch.tensor, n_resources: int = 3):
    query_embedding = embedding_model.encode(query, convert_to_tensor=True)
    
    dot_scores = util.dot_score(query_embedding, embeddings)[0]
    
    scores, indices = torch.topk(input=dot_scores, k=n_resources)
    
    return scores, indices

query = "What is rank one model editing and which modules does it modify?"
scores, indices = retrieve_relevant_resources(query, embeddings)

context_items = [pages_and_chunks[i] for i in indices]

# %% [markdown]
# ## Augmentation and Generation

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")
if not api_key:
    raise ValueError("GEMINI_API_KEY environment variable not found. Please set it before running.")

genai.configure(api_key=api_key)

llm_model = genai.GenerativeModel('gemini-2.5-flash')

def prompt_formatter(query: str, context_items: list[dict]) -> str:
    """Formats the retrieved context and query into a prompt."""
    context = "- " + "\n- ".join([item["sentence_chunk"] for item in context_items])
    
    prompt = f"""Based on the following context items, please answer the query.
Give yourself room to think by extracting relevant passages from the context before answering the query.
Make sure your answers are as explanatory as possible based ONLY on the context.

Context:
{context}

Query: {query}
Answer:"""
    
    return prompt

prompt = prompt_formatter(query, context_items)

outputs = llm_model.generate_content(
    prompt,
    generation_config=genai.types.GenerationConfig(
        max_output_tokens=2048,
        temperature=0.7,
    )
)

final_answer = outputs.text

print(f"RAG Output:\n{final_answer}")
# Out:
# RAG Output:
# Rank-One Model Editing (ROME) is a model editing technique whose update process consists of three main steps: key selection, value optimization, and v insertion.
#
# ROME modifies the **MLP layers** of the transformer network. Specifically, the intervention is performed at **layer 18**. This layer is identified as the center of causal effect in MLP layers and is approximately where MLP outputs begin to switch from acting as keys to values. The editing results from ROME confirm the importance of these mid-layer MLP layers.
